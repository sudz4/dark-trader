# %%
# libs
import os
import pandas as pd
import requests
from dotenv import load_dotenv #pip3 install python-dotenv
# load secrets
load_dotenv()
import math
import json
from IPython.display import JSON

# %%
# iex cloud - api data request
iex_key = os.getenv("IEX_API_KEY")
url = 'https://cloud.iexapis.com/stable/ref-data/symbols?token=' + iex_key
response = requests.get(url)
data = response.json()
symbols_df = pd.DataFrame(data)

# NYSE and NASDAQ symbols only (filter)
symbols_df = symbols_df[symbols_df['exchange'].isin(['XNYS', 'XNAS'])]

# select cols
symbols_df = symbols_df[['symbol', 'exchange', 'exchangeName']]

# filter df
print(symbols_df.head())
data_size = len(symbols_df.index)
print()
print(f"Data size: {data_size}") # get length of dataframe
# Out:
#   symbol exchange                 exchangeName
# 0      A     XNYS  New York Stock Exchange Inc
# 1     AA     XNYS  New York Stock Exchange Inc
# 4   AACG     XNAS           Nasdaq All Markets
# 5   AACI     XNAS           Nasdaq All Markets
# 6  AACIU     XNAS           Nasdaq All Markets
#
# Data size: 7791

# %%
# Function modified for better error handling
def fetch_quote_data(symbols_batch, iex_key):
    symbols_str = ','.join(symbols_batch)
    url = f'https://cloud.iexapis.com/stable/stock/market/batch?symbols={symbols_str}&types=quote&token={iex_key}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data for batch: {symbols_batch}. Status code: {response.status_code}, Response: {response.text}")
        return {}

# Correctly define batch_size
batch_size = 100
total_batches = math.ceil(len(symbols_df) / batch_size)
print(f"Total batches: {total_batches}")
    
# initialize a counter for completed batches
completed_batches = 0

# define the length of the progress bar
progress_bar_length = 50

"""scalable endpoint variable data request"""

quote_data_list = []

for i in range(0, len(symbols_df), batch_size):
    batch_symbols = symbols_df['symbol'].iloc[i:i+batch_size].tolist()
    batch_data = fetch_quote_data(batch_symbols, iex_key)
    
    # process and append data for each symbol in the batch
    for symbol in batch_symbols:
        quote_data = batch_data.get(symbol, {}).get('quote', {})
        quote_data_list.append({
            'symbol': symbol, # KEY
            'marketCap': quote_data.get('marketCap', None),
            'latestPrice': quote_data.get('latestPrice', None),
            'close': quote_data.get('close', None), # 'close': 'latestPrice' or 'previousClose
            'previousClose': quote_data.get('previousClose', None),
            'extendedPrice': quote_data.get('extendedPrice', None), 
            'extendedChange': quote_data.get('extendedChange', None), 
            'extendedChangePercent': quote_data.get('extendedChangePercent', None), 
            'latestVolume': quote_data.get('latestVolume', None), # after hours volume
            'volume': quote_data.get('volume', None), # market hours volume
            'previousVolume': quote_data.get('previousVolume', None), # previous day volume
            'iexVolume': quote_data.get('iexVolume', None), # IEX volume
            'primaryExchange': quote_data.get('primaryExchange', None),
            'avgTotalVolume': quote_data.get('avgTotalVolume', None),
            'calculationPrice': quote_data.get('calculationPrice', None),
            'change': quote_data.get('change', None),
            'changePercent': quote_data.get('changePercent', None),
            'companyName': quote_data.get('companyName', None),})
    
    # increment completed batches counter
    completed_batches += 1

    # calculate progress
    progress = (completed_batches / total_batches)
    filled_length = int(round(progress_bar_length * progress))
    
    # create progress bar
    bar = '█' * filled_length + '-' * (progress_bar_length - filled_length)
    
    # print progress bar with percentage
    print(f"\rProgress: |{bar}| {progress*100:.2f}% Complete", end="\r")

# Convert the combined data into a DataFrame
quote_df = pd.DataFrame(quote_data_list)
# Out:
# Total batches: 78
# Error fetching data for batch: ['A', 'AA', 'AACG', 'AACI', 'AACIU', 'AACT', 'AACT+', 'AACT=', 'AADI', 'AADR', 'AAGR', 'AAL', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP', 'AAPB', 'AAPD', 'AAPL', 'AAPU', 'AAT', 'AAXJ', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABCS', 'ABEO', 'ABEV', 'ABG', 'ABIO', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABLVW', 'ABM', 'ABNB', 'ABOS', 'ABR', 'ABR-D', 'ABR-E', 'ABR-F', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVX', 'AC', 'ACA', 'ACAB', 'ACABU', 'ACAC', 'ACACU', 'ACACW', 'ACAD', 'ACAH', 'ACAHU', 'ACAHW', 'ACB', 'ACBA', 'ACBAU', 'ACBAW', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHR', 'ACHR+', 'ACHV', 'ACI', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACON', 'ACONW', 'ACOR', 'ACP', 'ACP-A', 'ACR', 'ACR-C', 'ACR-D', 'ACRE', 'ACRS']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['ACRV', 'ACST', 'ACT', 'ACTG', 'ACV', 'ACVA', 'ACWI', 'ACWX', 'ACXP', 'ADAG', 'ADAP', 'ADBE', 'ADC', 'ADC-A', 'ADCT', 'ADD', 'ADEA', 'ADI', 'ADIL', 'ADM', 'ADMA', 'ADN', 'ADNT', 'ADNWW', 'ADOC', 'ADOCR', 'ADOCW', 'ADP', 'ADPT', 'ADSE', 'ADSEW', 'ADSK', 'ADT', 'ADTH', 'ADTHW', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADX', 'ADXN', 'AEAE', 'AEAEU', 'AEE', 'AEFC', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEL', 'AEL-A', 'AEL-B', 'AEM', 'AEMD', 'AENT', 'AENTW', 'AEO', 'AEP', 'AER', 'AERT', 'AERTW', 'AES', 'AESI', 'AEVA', 'AEVA+', 'AEYE', 'AEZS', 'AFAR', 'AFARU', 'AFB', 'AFBI', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFIB', 'AFJK', 'AFJKR', 'AFJKU', 'AFL', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFT', 'AFYA', 'AG', 'AGAE', 'AGBA', 'AGBAW', 'AGCO', 'AGD', 'AGEN', 'AGFY', 'AGI']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['AGIO', 'AGL', 'AGM', 'AGM-C', 'AGM-D', 'AGM-E', 'AGM-F', 'AGM-G', 'AGM.A', 'AGMH', 'AGNC', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGO', 'AGR', 'AGRI', 'AGRIW', 'AGRO', 'AGRX', 'AGS', 'AGTI', 'AGX', 'AGYS', 'AGZD', 'AHCO', 'AHG', 'AHH', 'AHH-A', 'AHI', 'AHL-C', 'AHL-D', 'AHL-E', 'AHR', 'AHT', 'AHT-D', 'AHT-F', 'AHT-G', 'AHT-H', 'AHT-I', 'AI', 'AIA', 'AIB', 'AIBBR', 'AIBBU', 'AIF', 'AIG', 'AIG-A', 'AIH', 'AIHS', 'AIMAU', 'AIMBU', 'AIMD', 'AIMDW', 'AIN', 'AIO', 'AIP', 'AIQ', 'AIR', 'AIRC', 'AIRE', 'AIRG', 'AIRL', 'AIRR', 'AIRS', 'AIRT', 'AIRTP', 'AISP', 'AISPW', 'AIT', 'AITR', 'AITRR', 'AITRU', 'AIU', 'AIV', 'AIXI', 'AIZ', 'AIZN', 'AJG', 'AJX', 'AJXA', 'AKA', 'AKAM', 'AKAN', 'AKBA', 'AKLI', 'AKO.A', 'AKO.B', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKYA', 'AL', 'AL-A', 'ALAR', 'ALB']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['ALBT', 'ALC', 'ALCC', 'ALCE', 'ALCO', 'ALCY', 'ALCYU', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIM', 'ALIT', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALL-B', 'ALL-H', 'ALL-I', 'ALL-J', 'ALLE', 'ALLG', 'ALLK', 'ALLO', 'ALLR', 'ALLT', 'ALLY', 'ALNT', 'ALNY', 'ALOT', 'ALPN', 'ALPP', 'ALRM', 'ALRN', 'ALRS', 'ALSA', 'ALSAR', 'ALSAU', 'ALSN', 'ALT', 'ALTG', 'ALTG-A', 'ALTI', 'ALTM', 'ALTO', 'ALTR', 'ALTU', 'ALTUU', 'ALTUW', 'ALTY', 'ALUR', 'ALUR+', 'ALV', 'ALVO', 'ALVR', 'ALX', 'ALXO', 'ALZN', 'AM', 'AMAL', 'AMAM', 'AMAT', 'AMBA', 'AMBC', 'AMBP', 'AMBP+', 'AMC', 'AMCR', 'AMCX', 'AMD', 'AMDS', 'AME', 'AMED', 'AMEH', 'AMG', 'AMGN', 'AMH', 'AMH-G', 'AMH-H', 'AMID', 'AMIX', 'AMK', 'AMKR', 'AMLI', 'AMLX', 'AMN', 'AMNB', 'AMP', 'AMPG', 'AMPGW', 'AMPH', 'AMPL', 'AMPS']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: 
LC', 'ATLCL', 'ATLCP', 'ATLCZ', 'ATLO', 'ATLX', 'ATMC', 'ATMCR', 'ATMCU', 'ATMU', 'ATMV', 'ATMVR', 'ATMVU', 'ATNF', 'ATNFW', 'ATNI', 'ATO', 'ATOM', 'ATOS', 'ATPC', 'ATR', 'ATRA', 'ATRC', 'ATRI', 'ATRO', 'ATS', 'ATSG', 'ATUS', 'ATXG', 'ATXI', 'ATXS', 'AU', 'AUB', 'AUB-A', 'AUBN', 'AUDC', 'AUGX', 'AUID', 'AUMI', 'AUPH', 'AUR', 'AURA', 'AUTL', 'AUUD', 'AUUDW', 'AUVI', 'AUVIP', 'AVA', 'AVAH', 'AVAL', 'AVAV', 'AVB', 'AVBP', 'AVD', 'AVDL', 'AVDX', 'AVGO', 'AVGR', 'AVHI', 'AVHIU', 'AVIR', 'AVK', 'AVNS', 'AVNT', 'AVNW', 'AVO']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['AVPT', 'AVRO', 'AVT', 'AVTE', 'AVTR', 'AVTX', 'AVXL', 'AVY', 'AWF', 'AWH', 'AWI', 'AWIN', 'AWINW', 'AWK', 'AWP', 'AWR', 'AWRE', 'AX', 'AXDX', 'AXGN', 'AXL', 'AXNX', 'AXON', 'AXP', 'AXR', 'AXS', 'AXS-E', 'AXSM', 'AXTA', 'AXTI', 'AY', 'AYI', 'AYRO', 'AYTU', 'AYX', 'AZ', 'AZEK', 'AZN', 'AZO', 'AZPN', 'AZTA', 'AZUL', 'AZZ', 'B', 'BA', 'BABA', 'BABX', 'BAC', 'BAC-B', 'BAC-E', 'BAC-K', 'BAC-L', 'BAC-M', 'BAC-N', 'BAC-O', 'BAC-P', 'BAC-Q', 'BAC-S', 'BACK', 'BAER', 'BAERW', 'BAFN', 'BAH', 'BAK', 'BALL', 'BALY', 'BAM', 'BANC', 'BANC-F', 'BAND', 'BANF', 'BANFP', 'BANL', 'BANR', 'BANX', 'BAOS', 'BAP', 'BARK', 'BARK+', 'BASE', 'BATRA', 'BATRK', 'BAX', 'BAYA', 'BAYAR', 'BAYAU', 'BB', 'BBAI', 'BBAI+', 'BBAR', 'BBCP', 'BBD', 'BBDC', 'BBDO', 'BBGI', 'BBH', 'BBIO', 'BBLG', 'BBLGW', 'BBN']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['BBSI', 'BBU', 'BBUC', 'BBVA', 'BBW', 'BBWI', 'BBY', 'BC', 'BC-C', 'BCAB', 'BCAL', 'BCAN', 'BCAT', 'BCBP', 'BCC', 'BCDA', 'BCDAW', 'BCE', 'BCEL', 'BCH', 'BCLI', 'BCML', 'BCO', 'BCOV', 'BCOW', 'BCPC', 'BCRX', 'BCS', 'BCSA', 'BCSAU', 'BCSF', 'BCTX', 'BCTXW', 'BCX', 'BCYC', 'BDC', 'BDGS', 'BDJ', 'BDN', 'BDRX', 'BDSX', 'BDTX', 'BDX', 'BE', 'BEAM', 'BEAT', 'BEATW', 'BECN', 'BEDU', 'BEEM', 'BEEMW', 'BEEZ', 'BEKE', 'BELFA', 'BELFB', 'BEN', 'BENF', 'BENFW', 'BEP', 'BEP-A', 'BEPC', 'BEPH', 'BEPI', 'BERY', 'BEST', 'BETR', 'BETRW', 'BETS', 'BF.A', 'BF.B', 'BFAC', 'BFAC+', 'BFAC=', 'BFAM', 'BFC', 'BFH', 'BFI', 'BFIIW', 'BFIN', 'BFK', 'BFLY', 'BFLY+', 'BFRG', 'BFRGW', 'BFRI', 'BFRIW', 'BFS', 'BFS-D', 'BFS-E', 'BFST', 'BFX', 'BFZ', 'BG', 'BGB', 'BGC', 'BGFV', 'BGH', 'BGLC', 'BGNE', 'BGR']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['BGRN', 'BGS', 'BGSF', 'BGT', 'BGX', 'BGXX', 'BGY', 'BH', 'BH.A', 'BHAC', 'BHACU', 'BHAT', 'BHC', 'BHE', 'BHF', 'BHFAL', 'BHFAM', 'BHFAN', 'BHFAO', 'BHFAP', 'BHIL', 'BHK', 'BHLB', 'BHP', 'BHR', 'BHR-B', 'BHR-D', 'BHRB', 'BHV', 'BHVN', 'BIAF', 'BIAFW', 'BIB', 'BIDU', 'BIG', 'BIGC', 'BIGZ', 'BIIB', 'BILI', 'BILL', 'BIMI', 'BIO', 'BIO.B', 'BIOL', 'BIOR', 'BIOX', 'BIP', 'BIP-A', 'BIP-B', 'BIPC', 'BIPH', 'BIPI', 'BIRD', 'BIRK', 'BIS', 'BIT', 'BITF', 'BITS', 'BIVI', 'BJ', 'BJDX', 'BJK', 'BJRI', 'BK', 'BKCC', 'BKCH', 'BKD', 'BKDT', 'BKE', 'BKH', 'BKIV', 'BKKT', 'BKKT+', 'BKN', 'BKNG', 'BKR', 'BKSY', 'BKSY+', 'BKT', 'BKU', 'BKWO', 'BKYI', 'BL', 'BLAC', 'BLACR', 'BLACU', 'BLACW', 'BLBD', 'BLBX', 'BLCN', 'BLCO', 'BLCR', 'BLD', 'BLDE', 'BLDEW', 'BLDP', 'BLDR', 'BLE', 'BLEU', 'BLEUR']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['BLEUU', 'BLEUW', 'BLFS', 'BLFY', 'BLIN', 'BLK', 'BLKB', 'BLLD', 'BLMN', 'BLND', 'BLNK', 'BLRX', 'BLTE', 'BLUE', 'BLW', 'BLX', 'BLZE', 'BMA', 'BMBL', 'BME', 'BMEA', 'BMEZ', 'BMI', 'BML-G', 'BML-H', 'BML-J', 'BML-L', 'BMN', 'BMO', 'BMR', 'BMRA', 'BMRC', 'BMRN', 'BMY', 'BN', 'BND', 'BNDW', 'BNDX', 'BNED', 'BNGO', 'BNH', 'BNIX', 'BNIXR', 'BNIXW', 'BNJ', 'BNL', 'BNOX', 'BNR', 'BNRE', 'BNRE.A', 'BNRG', 'BNS', 'BNTC', 'BNTX', 'BNY', 'BNZI', 'BNZIW', 'BOC', 'BOCN', 'BOCNU', 'BODY', 'BOE', 'BOF', 'BOH', 'BOH-A', 'BOKF', 'BOLT', 'BON', 'BOND', 'BOOM', 'BOOT', 'BORR', 'BOSC', 'BOTJ', 'BOTZ', 'BOWL', 'BOWN', 'BOWNR', 'BOWNU', 'BOX', 'BOXL', 'BP', 'BPMC', 'BPOP', 'BPOPM', 'BPRN', 'BPT', 'BPTH', 'BPTS', 'BPYPM', 'BPYPN', 'BPYPO', 'BPYPP', 'BR', 'BRAC', 'BRACR', 'BRACU', 'BRAG', 'BRBR', 'BRC']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: 
. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['CHT', 'CHTR', 'CHUY', 'CHW', 'CHWY', 'CHX', 'CHY', 'CI', 'CIA', 'CIB', 'CIBR', 'CID', 'CIEN', 'CIF', 'CIFR', 'CIG', 'CIG.C', 'CIGI', 'CII', 'CIL', 'CIM', 'CIM-A', 'CIM-B', 'CIM-C', 'CIM-D', 'CINF', 'CING', 'CINGW', 'CINT', 'CIO', 'CIO-A', 'CION', 'CISO', 'CISS', 'CITE', 'CITEU', 'CIVB', 'CIVI', 'CIZ', 'CJET', 'CJJD', 'CKPT', 'CL', 'CLAR', 'CLB', 'CLBK', 'CLBR', 'CLBR+', 'CLBR=', 'CLBT', 'CLCO', 'CLDT', 'CLDT-A', 'CLDX', 'CLEU', 'CLF', 'CLFD', 'CLGN', 'CLH', 'CLIR', 'CLLS', 'CLMB', 'CLMT', 'CLNE', 'CLNN', 'CLNNW', 'CLOA', 'CLOD', 'CLOE', 'CLOER', 'CLOEU', 'CLOU', 'CLOV', 'CLPR', 'CLPS', 'CLPT', 'CLRB', 'CLRC', 'CLRCR', 'CLRCU', 'CLRO', 'CLS', 'CLSD', 'CLSK', 'CLSM', 'CLST', 'CLVR', 'CLVRW', 'CLVT', 'CLVT-A', 'CLW', 'CLWT', 'CLX', 'CM', 'CMA', 'CMAX', 'CMBM', 'CMC', 'CMCA', 'CMCAU']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['CMCM', 'CMCO', 'CMCSA', 'CMCT', 'CME', 'CMG', 'CMI', 'CMLS', 'CMMB', 'CMND', 'CMP', 'CMPO', 'CMPR', 'CMPS', 'CMPX', 'CMRE', 'CMRE-B', 'CMRE-C', 'CMRE-D', 'CMRE-E', 'CMRX', 'CMS', 'CMS-B', 'CMS-C', 'CMSA', 'CMSC', 'CMSD', 'CMTG', 'CMTL', 'CMU', 'CNA', 'CNC', 'CNCR', 'CNDA', 'CNDA+', 'CNDA=', 'CNDB', 'CNDB+', 'CNDB=', 'CNDT', 'CNET', 'CNEY', 'CNF', 'CNFR', 'CNFRZ', 'CNGL', 'CNGLU', 'CNGLW', 'CNHI', 'CNI', 'CNK', 'CNM', 'CNMD', 'CNNE', 'CNO', 'CNO-A', 'CNOB', 'CNOBP', 'CNP', 'CNQ', 'CNS', 'CNSL', 'CNSP', 'CNTA', 'CNTB', 'CNTG', 'CNTX', 'CNTY', 'CNVS', 'CNX', 'CNXA', 'CNXC', 'CNXN', 'COCH', 'COCHW', 'COCO', 'COCP', 'CODA', 'CODI', 'CODI-A', 'CODI-B', 'CODI-C', 'CODX', 'COEP', 'COEPW', 'COF', 'COF-I', 'COF-J', 'COF-K', 'COF-L', 'COF-N', 'COFS', 'COGT', 'COHR', 'COHU', 'COIN', 'COKE', 'COLB', 'COLD', 'COLL']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['COLM', 'COMM', 'COMP', 'COMS', 'COMT', 'CONL', 'CONN', 'CONX', 'CONXU', 'CONXW', 'COO', 'COOK', 'COOL', 'COOLU', 'COOLW', 'COOP', 'COP', 'COPJ', 'COR', 'CORT', 'CORZ', 'CORZZ', 'COSM', 'COST', 'COTY', 'COUR', 'COWG', 'COWS', 'COYA', 'CP', 'CPA', 'CPAC', 'CPB', 'CPBI', 'CPE', 'CPF', 'CPG', 'CPHC', 'CPIX', 'CPK', 'CPLP', 'CPLS', 'CPNG', 'CPOP', 'CPRI', 'CPRT', 'CPRX', 'CPS', 'CPSH', 'CPSI', 'CPSS', 'CPT', 'CPTN', 'CPTNW', 'CPZ', 'CQP', 'CR', 'CRAI', 'CRBG', 'CRBP', 'CRBU', 'CRC', 'CRCT', 'CRD.A', 'CRD.B', 'CRDF', 'CRDL', 'CRDO', 'CREG', 'CRESW', 'CRESY', 'CREV', 'CREVW', 'CREX', 'CRGE', 'CRGO', 'CRGX', 'CRGY', 'CRH', 'CRI', 'CRIS', 'CRK', 'CRKN', 'CRL', 'CRM', 'CRMD', 'CRMT', 'CRNC', 'CRNT', 'CRNX', 'CRON', 'CROX', 'CRS', 'CRSP', 'CRSR', 'CRT', 'CRTO', 'CRUS', 'CRVL', 'CRVO']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['CRVS', 'CRWD', 'CRWS', 'CSA', 'CSAN', 'CSB', 'CSBR', 'CSCO', 'CSF', 'CSGP', 'CSGS', 'CSIQ', 'CSL', 'CSLM', 'CSLMR', 'CSLMU', 'CSLMW', 'CSLR', 'CSLRW', 'CSML', 'CSPI', 'CSQ', 'CSR', 'CSR-C', 'CSSE', 'CSSEL', 'CSSEN', 'CSSEP', 'CSTE', 'CSTL', 'CSTM', 'CSTR', 'CSV', 'CSWC', 'CSWCZ', 'CSWI', 'CSX', 'CTA-A', 'CTA-B', 'CTAS', 'CTBB', 'CTBI', 'CTCX', 'CTCXW', 'CTDD', 'CTEC', 'CTHR', 'CTKB', 'CTLP', 'CTLT', 'CTMX', 'CTNT', 'CTO', 'CTO-A', 'CTOS', 'CTOS+', 'CTR', 'CTRA', 'CTRE', 'CTRM', 'CTRN', 'CTS', 'CTSH', 'CTSO', 'CTV', 'CTV+', 'CTVA', 'CTXR', 'CUBA', 'CUBB', 'CUBE', 'CUBI', 'CUBI-E', 'CUBI-F', 'CUE', 'CUK', 'CULL', 'CULP', 'CURI', 'CURIW', 'CURO', 'CURV', 'CUTR', 'CUZ', 'CVAC', 'CVBF', 'CVCO', 'CVCY', 'CVE', 'CVE+', 'CVEO', 'CVGI', 'CVGW', 'CVI', 'CVII', 'CVKD', 'CVLG', 'CVLT', 'CVLY', 'CVNA']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['CVRX', 'CVS', 'CVV', 'CVX', 'CW', 'CWAN', 'CWBC', 'CWCO', 'CWD', 'CWEN', 'CWEN.A', 'CWH', 'CWK', 'CWST', 'CWT', 'CX', 'CXAI', 'CXAIW', 'CXDO', 'CXE', 'CXH', 'CXM', 'CXSE', 'CXT', 'CXW', 'CYAN', 'CYBR', 'CYCC', 'CYCCP', 'CYCN', 'CYD', 'CYH', 'CYN', 'CYRX', 'CYT', 'CYTH', 'CYTHW', 'CYTK', 'CYTO', 'CZAR', 'CZFS', 'CZNC', 'CZOO', 'CZR', 'CZWI', 'D', 'DAC', 'DADA', 'DAIO', 'DAKT', 'DAL', 'DALI', 'DALN', 'DAN', 'DAO', 'DAPP', 'DAR', 'DARE', 'DASH', 'DATS', 'DATSW', 'DAVA', 'DAVE', 'DAWN', 'DAX', 'DAY', 'DB', 'DBD', 'DBGI', 'DBGIW', 'DBI', 'DBL', 'DBRG', 'DBRG-H', 'DBRG-I', 'DBRG-J', 'DBVT', 'DBX', 'DCBO', 'DCF', 'DCFC', 'DCGO', 'DCI', 'DCO', 'DCOM', 'DCOMP', 'DCPH', 'DCTH', 'DD', 'DDD', 'DDI', 'DDIV', 'DDL', 'DDOG', 'DDS', 'DDT', 'DE', 'DEA', 'DEC', 'DECA']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['DECAU', 'DECK', 'DEI', 'DELL', 'DEMZ', 'DENN', 'DEO', 'DERM', 'DESP', 'DFGP', 'DFGX', 'DFH', 'DFIN', 'DFLI', 'DFLIW', 'DFP', 'DFS', 'DG', 'DGCB', 'DGHI', 'DGICA', 'DGICB', 'DGII', 'DGLY', 'DGRE', 'DGRS', 'DGRW', 'DGX', 'DH', 'DHAC', 'DHACU', 'DHACW', 'DHAI', 'DHAIW', 'DHC', 'DHCA', 'DHCAU', 'DHCAW', 'DHCNI', 'DHCNL', 'DHF', 'DHI', 'DHIL', 'DHR', 'DHT', 'DHX', 'DIAX', 'DIBS', 'DIN', 'DINO', 'DIOD', 'DIP', 'DIS', 'DIST', 'DISTR', 'DIVD', 'DJCO', 'DK', 'DKL', 'DKNG', 'DKS', 'DLB', 'DLHC', 'DLNG', 'DLNG-A', 'DLNG-B', 'DLO', 'DLPN', 'DLR', 'DLR-J', 'DLR-K', 'DLR-L', 'DLTH', 'DLTR', 'DLX', 'DLY', 'DM', 'DMA', 'DMAC', 'DMAT', 'DMB', 'DMLP', 'DMO', 'DMRC', 'DMTK', 'DMXF', 'DNA', 'DNA+', 'DNB', 'DNLI', 'DNMR', 'DNOW', 'DNP', 'DNTH', 'DNUT', 'DO', 'DOC', 'DOCN', 'DOCS', 'DOCU']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['DOGZ', 'DOLE', 'DOMA', 'DOMH', 'DOMO', 'DOOO', 'DOOR', 'DORM', 'DOUG', 'DOV', 'DOW', 'DOX', 'DOYU', 'DPCS', 'DPCSU', 'DPG', 'DPRO', 'DPZ', 'DQ', 'DRCT', 'DRD', 'DRH', 'DRH-A', 'DRI', 'DRIO', 'DRIV', 'DRLL', 'DRMA', 'DRMAW', 'DRQ', 'DRRX', 'DRS', 'DRTS', 'DRTSW', 'DRUG', 'DRVN', 'DSAQ', 'DSAQ=', 'DSGN', 'DSGR', 'DSGX', 'DSKE', 'DSL', 'DSM', 'DSMC', 'DSP', 'DSTX', 'DSU', 'DSWL', 'DSX', 'DSX+', 'DSX-B', 'DT', 'DTB', 'DTC', 'DTCK', 'DTE', 'DTF', 'DTG', 'DTI', 'DTIL', 'DTM', 'DTSS', 'DTST', 'DTSTW', 'DTW', 'DUET', 'DUETU', 'DUK', 'DUK-A', 'DUKB', 'DUO', 'DUOL', 'DUOT', 'DV', 'DVA', 'DVAL', 'DVAX', 'DVLU', 'DVN', 'DVOL', 'DVY', 'DWAC', 'DWACU', 'DWAS', 'DWAW', 'DWSH', 'DWSN', 'DWUS', 'DX', 'DX-C', 'DXC', 'DXCM', 'DXJS', 'DXLG', 'DXPE', 'DXR', 'DXYN', 'DY', 'DYAI']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['DYFI', 'DYN', 'DYNI', 'DYNT', 'DYTA', 'DZSI', 'E', 'EA', 'EAC', 'EACPU', 'EACPW', 'EAF', 'EAI', 'EARN', 'EAST', 'EAT', 'EB', 'EBAY', 'EBC', 'EBF', 'EBIZ', 'EBMT', 'EBON', 'EBR', 'EBR.B', 'EBS', 'EBTC', 'EC', 'ECAT', 'ECBK', 'ECC', 'ECC-D', 'ECCC', 'ECCF', 'ECCV', 'ECCW', 'ECCX', 'ECDA', 'ECDAW', 'ECL', 'ECO', 'ECOR', 'ECOW', 'ECPG', 'ECVT', 'ECX', 'ECXWW', 'ED', 'EDAP', 'EDBL', 'EDBLW', 'EDD', 'EDF', 'EDIT', 'EDN', 'EDOC', 'EDR', 'EDRY', 'EDSA', 'EDTK', 'EDU', 'EDUC', 'EE', 'EEA', 'EEFT', 'EEIQ', 'EEMA', 'EEX', 'EFAS', 'EFC', 'EFC-A', 'EFC-B', 'EFC-C', 'EFC-D', 'EFC-E', 'EFOI', 'EFR', 'EFRA', 'EFSC', 'EFSCP', 'EFT', 'EFTR', 'EFTRW', 'EFX', 'EFXT', 'EG', 'EGAN', 'EGBN', 'EGF', 'EGHT', 'EGIO', 'EGLE', 'EGO', 'EGOX', 'EGP', 'EGRX', 'EGY', 'EH', 'EHAB', 'EHC']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['EHI', 'EHTH', 'EIC', 'EICA', 'EICB', 'EIG', 'EIGR', 'EIX', 'EJH', 'EKG', 'EKSO', 'EL', 'ELAB', 'ELAN', 'ELBM', 'ELC', 'ELDN', 'ELEV', 'ELF', 'ELME', 'ELP', 'ELPC', 'ELS', 'ELSE', 'ELTK', 'ELTX', 'ELUT', 'ELV', 'ELVA', 'ELVN', 'ELWS', 'ELYM', 'EM', 'EMB', 'EMBC', 'EMCB', 'EMCG', 'EMCGR', 'EMCGU', 'EMD', 'EME', 'EMF', 'EMIF', 'EMKR', 'EML', 'EMLD', 'EMLDU', 'EMN', 'EMO', 'EMP', 'EMR', 'EMXC', 'EMXF', 'ENB', 'ENCP', 'ENCPU', 'ENFN', 'ENG', 'ENGN', 'ENGNW', 'ENIC', 'ENJ', 'ENLC', 'ENLT', 'ENLV', 'ENO', 'ENOV', 'ENPH', 'ENR', 'ENS', 'ENSC', 'ENSG', 'ENTA', 'ENTG', 'ENTR', 'ENTX', 'ENV', 'ENVA', 'ENVB', 'ENVX', 'ENZ', 'ENZL', 'EOD', 'EOG', 'EOI', 'EOLS', 'EOS', 'EOSE', 'EOSEW', 'EOT', 'EP-C', 'EPAC', 'EPAM', 'EPC', 'EPD', 'EPIX', 'EPOW', 'EPR', 'EPR-C', 'EPR-E']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['EPR-G', 'EPRT', 'EPSN', 'EQ', 'EQBK', 'EQC', 'EQC-D', 'EQH', 'EQH-A', 'EQH-C', 'EQIX', 'EQNR', 'EQR', 'EQRR', 'EQS', 'EQT', 'ERAS', 'ERET', 'ERF', 'ERIC', 'ERIE', 'ERII', 'ERJ', 'ERNA', 'ERO', 'ERSX', 'ES', 'ESAB', 'ESAC', 'ESACU', 'ESCA', 'ESE', 'ESEA', 'ESGD', 'ESGE', 'ESGL', 'ESGR', 'ESGRO', 'ESGRP', 'ESGU', 'ESHA', 'ESHAR', 'ESI', 'ESLA', 'ESLAW', 'ESLT', 'ESMV', 'ESNT', 'ESOA', 'ESPO', 'ESPR', 'ESQ', 'ESRT', 'ESS', 'ESSA', 'ESTA', 'ESTC', 'ET', 'ET-E', 'ET-I', 'ETB', 'ETD', 'ETEC', 'ETG', 'ETI-', 'ETJ', 'ETN', 'ETNB', 'ETO', 'ETON', 'ETR', 'ETRN', 'ETSY', 'ETV', 'ETW', 'ETWO', 'ETWO+', 'ETX', 'ETY', 'EU', 'EUDA', 'EUDAW', 'EUFN', 'EURN', 'EVA', 'EVAX', 'EVBG', 'EVC', 'EVCM', 'EVER', 'EVEX', 'EVEX+', 'EVF', 'EVG', 'EVGN', 'EVGO', 'EVGR', 'EVGRU', 'EVH', 'EVLV']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Error fetching data for batch: ['EVLVW', 'EVMT', 'EVN', 'EVO', 'EVOK', 'EVR', 'EVRG', 'EVRI', 'EVT', 'EVTC', 'EVTL', 'EVTL+', 'EVTV', 'EW', 'EWBC', 'EWCZ', 'EWJV', 'EWTX', 'EWZS', 'EXAI', 'EXAS', 'EXC', 'EXEL', 'EXFY', 'EXG', 'EXK', 'EXLS', 'EXP', 'EXPD', 'EXPE', 'EXPI', 'EXPO', 'EXPR', 'EXR', 'EXTO', 'EXTR', 'EYE', 'EYEG', 'EYEN', 'EYPT', 'EZFL', 'EZGO', 'EZPW', 'F', 'FA', 'FAAR', 'FAB', 'FAD', 'FAF', 'FALN', 'FAM', 'FAMI', 'FANG', 'FANH', 'FARM', 'FARO', 'FAST', 'FAT', 'FATBB', 'FATBP', 'FATBW', 'FATE', 'FATH', 'FAZE', 'FAZEW', 'FBIN', 'FBIO', 'FBIOP', 'FBIZ', 'FBK', 'FBL', 'FBLG', 'FBMS', 'FBNC', 'FBOT', 'FBP', 'FBRT', 'FBRT-E', 'FBRX', 'FBYD', 'FBYDW', 'FBZ', 'FC', 'FCA', 'FCAL', 'FCAP', 'FCBC', 'FCCO', 'FCEF', 'FCEL', 'FCF', 'FCFS', 'FCN', 'FCNCA', 'FCNCO', 'FCNCP', 'FCPT', 'FCRX', 'FCT', 'FCUV']. Status code: 402, Response: Your account does not have the relevant IEX Cloud data bundle add-on for this data. Buy data bundle add-ons at https://iexcloud.io/console/manage-plan.
# Progress: |█████████████████---------------------------------| 33.33% Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 31
#      29 for i in range(0, len(symbols_df), batch_size):
#      30     batch_symbols = symbols_df['symbol'].iloc[i:i+batch_size].tolist()
# ---> 31     batch_data = fetch_quote_data(batch_symbols, iex_key)
#      33     # process and append data for each symbol in the batch
#      34     for symbol in batch_symbols:
#
# Cell In[10], line 5, in fetch_quote_data(symbols_batch, iex_key)
#       3 symbols_str = ','.join(symbols_batch)
#       4 url = f'https://cloud.iexapis.com/stable/stock/market/batch?symbols={symbols_str}&types=quote&token={iex_key}'
# ----> 5 response = requests.get(url)
#       6 if response.status_code == 200:
#       7     return response.json()
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File ~/Desktop/FINANCIAL-SYSTEMS/dark-trader/dt_venv/lib/python3.11/site-packages/urllib3/util/ssl_.py:445, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     443 if ca_certs or ca_cert_dir or ca_cert_data:
#     444     try:
# --> 445         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     446     except OSError as e:
#     447         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
quote_df.head(10)
# Out:
#   symbol marketCap latestPrice close previousClose extendedPrice  \
# 0      A      None        None  None          None          None
# 1     AA      None        None  None          None          None
# 2   AACG      None        None  None          None          None
# 3   AACI      None        None  None          None          None
# 4  AACIU      None        None  None          None          None
# 5   AACT      None        None  None          None          None
# 6  AACT+      None        None  None          None          None
# 7  AACT=      None        None  None          None          None
# 8   AADI      None        None  None          None          None
# 9   AADR      None        None  None          None          None
#
#   extendedChange extendedChangePercent latestVolume volume previousVolume  \
# 0           None                  None         None   None           None
# 1           None                  None         None   None           None
# 2           None                  None         None   None           None
# 3           None                  None         None   None           None
# 4           None                  None         None   None           None
# 5           None                  None         None   None           None
# 6           None                  None         None   None           None
# 7           None                  None         None   None           None
# 8           None                  None         None   None           None
# 9           None                  None         None   None           None
#
#   iexVolume primaryExchange avgTotalVolume calculationPrice change  \
# 0      None            None           None             None   None
# 1      None            None           None             None   None
# 2      None            None           None             None   None
# 3      None            None           None             None   None
# 4      None            None           None             None   None
# 5      None            None           None             None   None
# 6      None            None           None             None   None
# 7      None            None           None             None   None
# 8      None            None           None             None   None
# 9      None            None           None             None   None
#
#   changePercent companyName
# 0          None        None
# 1          None        None
# 2          None        None
# 3          None        None
# 4          None        None
# 5          None        None
# 6          None        None
# 7          None        None
# 8          None        None
# 9          None        None

# %%
# Merge with the screener_df
# screener_df = symbols_df.merge(quote_df[['symbol',
#                                         'latestPrice',
#                                         'previousClose', #MOVED UP
#                                         'extendedPrice', #NEW
#                                         'extendedChangePercent', #NEW #IMPORTANT
#                                         'extendedPriceTime', #NEW  
#                                         'latestVolume', #NEW
#                                         'companyName']], on='symbol', how='left')
